# %% [markdown]
# # Training UDEM
#
# This script performs the hyperparameter optimization of the attention U-Net and trains the model.
#
# python hpo_unet.py \
#   --projectDir /mnt/data/myproject \
#   --normalization detrended \
#   --storage sqlite:///hpo.db \
#   --n_trials 200 \
#   --n_jobs 4

# %%
study = run_hpo(n_trials=50)
print(study.best_trial.params)

# %% [markdown]
# python 104-run-optuna.py --projectDir /Users/rfk471/Dropbox/elevation-canada --normalization raw --n_trials 150 --n_jobs 1
