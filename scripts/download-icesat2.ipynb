# %% [markdown]
# # Download ICESat-2 data for validation

# %%
import earthaccess
import preprocessing_tools as ptools

# %%
projectDir = "/Users/rfk471/Dropbox/elevation-canada"

region_ids = ["01","02","03","04","05","06","07","08","09","10","11","12","13","14","15"]

# %% [markdown]
# ## Authenticate access to NASA Earthdata
#
# Downloading the ICESat-2 data through earthaccess requires an active NASA Earthdata account, see here: https://earthaccess.readthedocs.io/en/stable/

# %%
session = earthaccess.login(strategy="netrc")
assert session.authenticated, "Earthdata login failed."

# %% [markdown]
# ICESat-2 data is downloaded for all regional polygons. The data is downloaded on a seasonal basis where the data is interpolated onto the 100 m grid by taking the median of all data points within a pixel. A netcdf file is then saved for each region, containing all seasonal data from the launch of ICESat-2 through to fall 2024.

# %%
for region_id in region_ids:
    ptools.download_icesat2(region_id,projectDir)
# Out:
# === WINTER 2018 ===
# ⚠️ No ATL06 data found.
#
# === SPRING 2018 ===
# ⚠️ No ATL06 data found.
#
# === SUMMER 2018 ===
# ⚠️ No ATL06 data found.
#
# === FALL 2018 ===
# QUEUEING TASKS | :   0%|          | 0/116 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/116 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/116 [00:00<?, ?it/s]
# ✅ Downloaded ICESat-2
# ✅ Created gridded slice for fall 2018
#
# === WINTER 2019 ===
# QUEUEING TASKS | :   0%|          | 0/230 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/230 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/230 [00:00<?, ?it/s]
# ✅ Downloaded ICESat-2
# ✅ Created gridded slice for winter 2019
#
# === SPRING 2019 ===
# QUEUEING TASKS | :   0%|          | 0/243 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/243 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/243 [00:00<?, ?it/s]
# ✅ Downloaded ICESat-2
# ✅ Created gridded slice for spring 2019
#
# ...
